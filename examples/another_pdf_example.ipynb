# %%
using Pkg; Pkg.activate("..")

using Dao, PyPlot, Statistics
# Out:
# ┌ Info: Precompiling Dao [923aee56-57d8-11e9-2f0d-e3e88a113be6]
# └ @ Base loading.jl:1189
# ┌ Warning: Package Distributions does not have Test in its dependencies:
# │ - If you have Distributions checked out for development and have
# │   added Test as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with Distributions
# └ Loading Test into Distributions from project dependency, future warnings for Distributions are suppressed.
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Dao [923aee56-57d8-11e9-2f0d-e3e88a113be6]
# │   exception = ErrorException("Required dependency Distributions [31c24e10-a181-5473-b8eb-7969acd0382f] failed to load from a cache file.")
# └ @ Base loading.jl:966
# ┌ Info: Recompiling stale cache file /Users/gregorywagner/.julia/compiled/v1.0/Distributions/xILW0.ji for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
# └ @ Base loading.jl:1187
# ┌ Warning: Package Distributions does not have Test in its dependencies:
# │ - If you have Distributions checked out for development and have
# │   added Test as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with Distributions
# └ Loading Test into Distributions from project dependency, future warnings for Distributions are suppressed.

# %% [markdown]
# # The `LossFunction` in `Dao.jl`
#
# First, we construct a loss function, which computes the 'likelihood' --- or 'error' associated with an 'event' (or, in the case of a turbulence model, associated with the output of a turbulence model run with given parameters). Here we call the parameter $x$. The loss function takes three arguments: the parameter or array of parameters, `x`, a `model`, and `data` against which the model output is compared.
#
# For this example, we build a system in which the model is a probability distribution $p(x)$, independent from any data.
# We can interpret the probability distribution as modeling the likelihood that the parameter `x` is the 'true' parameter that minimizes model error.
#
# ## A simple probability distribution
#
# We use the probability distribution
#
# $$ p(x) = \frac{\mathrm{e}^{-(x+2)^2/2} + \mathrm{e}^{-(x-2)^2/2}}{2 \sqrt{2\pi}} $$

# %%
g(x) = exp(-x^2/2)
pdf(x) = (g(x+4) + g(x-4)) / (2*√(2π))

sample_x = range(-10, stop=10, step=0.01)

fig, axs = subplots()

plot(sample_x, pdf.(sample_x), label=L"p(x)")

title("A simple probability distribution")
ylim(0, 0.4)
xlabel(L"x")
ylabel(L"p(x)")
[axs.spines[spine].set_visible(false) for spine in ("top", "right")]
legend()

@show minimum(pdf.(sample_x))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# minimum(pdf.(sample_x)) = 3.037941424911643e-9
# 3.037941424911643e-9

# %% [markdown]
# ## Choosing the loss function
#
# We are free to choose the loss function as some sensible function of the model output.
# Here, we define the loss as the negative log of the probability distribution, so that
#
# $$ V(x, b) = - \log \big [ p(x) + b \big ] $$.
#
# Note that the mininum of the pdf is $0$, so as long s $b > 0$, the loss function is well-defined.

# %%
struct PDFModel
    pdf :: Function
end

compute_loss(x, model, data) = -log(model.pdf(x))
compute_dull_loss(x, model, data) = -log(model.pdf(x) + 0.1)

model = PDFModel(pdf)
loss = LossFunction(model, nothing, compute_loss, 10.0)
loss_sharp = LossFunction(model, nothing, compute_dull_loss, 10.0)

fig, axs = subplots()

plot(sample_x, pdf.(sample_x), label=L"p(x)")
plot(sample_x, loss.(sample_x)/loss.scale, "--", label=L"V(p)/r")
plot(sample_x, loss_sharp.(sample_x)/loss_sharp.scale, "--", label=L"V_\mathrm{sharp}(p)/r")

title("A simple probability distribution")
xlabel(L"x")
ylabel(L"p(x)")
[axs.spines[spine].set_visible(false) for spine in ("top", "right")]
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x12a939b00>

# %% [markdown]
# # Some example chains!
#
# ## Too-small perturbation with poor initial condition

# %%
initial_state = MarkovLink(loss, 8.0)
perturbation = NormalPerturbation(0.5)
markov_chain = MarkovChain(10^6, initial_state, loss, perturbation)

p_obs = errors(markov_chain)
x_obs = params(markov_chain)

plot(x_obs, p_obs, "o", fillstyle="none")
plot(sample_x, loss.(sample_x))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x149dbb4e0>

# %% [markdown]
# ## Large perturbation adequately sample the distribution

# %%
initial_state = MarkovLink(loss, 8.0)
perturbation = NormalPerturbation(4.0)
markov_chain = MarkovChain(10^4, initial_state, loss, perturbation)

p_obs = errors(markov_chain)
x_obs = params(markov_chain)

plot(x_obs, p_obs, "o", fillstyle="none")
plot(sample_x, loss.(sample_x))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x12aeef6d8>

# %% [markdown]
# ## Decent initial guess but too-small perturbations

# %%
initial_state = MarkovLink(loss, 0.0)
perturbation = NormalPerturbation(0.1)
markov_chain = MarkovChain(10^6, initial_state, loss, perturbation)

p_obs = errors(markov_chain)
x_obs = params(markov_chain)

plot(x_obs, p_obs, "o", fillstyle="none")
plot(sample_x, loss.(sample_x))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x15e46d588>

# %%
initial_state = MarkovLink(loss, 0.0)
perturbation = NormalPerturbation(2.0)
markov_chain = MarkovChain(10^8, initial_state, loss, perturbation)

p_obs = errors(markov_chain)
x_obs = params(markov_chain)

plot(x_obs, p_obs, "o", fillstyle="none")
plot(sample_x, loss.(sample_x))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x171aa6518>
